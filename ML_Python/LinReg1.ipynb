# %% [markdown]
# <h1><center>Linear Reggression</center></h1>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
print("HI")
# Out:
# HI

# %%
df = pd.read_csv("students.csv")
df.head()
# Out:
#    Hours  Score
# 0    2.5     21
# 1    3.3     33
# 2    8.5     96
# 3    2.5     30
# 4    1.5     20

# %%
# Splitting Features
x = df[["Hours"]]
y = df[["Score"]]

# %%
reg = LinearRegression().fit(x,y)

# %%
#Plot Data and Regression Line
plt.scatter(x, y, label="Data")
plt.plot(x, reg.predict(x), color="red", label="Linear Regression")
plt.xlabel(r"$Hours \rightarrow$")
plt.ylabel(r"$Score \rightarrow$")
plt.legend()
plt.show()

# %%
hour = 2.5
plt.plot(x1,reg.predict(x))

# %%
x1 = np.array(x)
x1.shape
# Out:
# (27, 1)
