# %% [markdown]
# ## Import

# %%
# Imports
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Distplot

# %%
# sns.distplot([0, 1, 2, 3, 4, 5])
sns.distplot([0, 1, 2, 3, 4, 5])

plt.show()
# Out:
# /tmp/ipykernel_3956/2565928778.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([0, 1, 2, 3, 4, 5])

# %% [markdown]
# ## Normal Distribution

# %%
# Generate a Random array
# x = np.random.normal(size=(2, 3))
# print(x)

# Generate a Random array with mean 1(loc) and standard deviation 2(scale)
x = np.random.normal(loc=1, scale=2, size=(2, 3))
print(x)

# Plotting
sns.distplot(np.random.normal(size=1000), hist=False)

plt.show()
# Out:
# [[ 1.1723156   3.22708829 -1.28864482]
#  [ 2.70692361  4.93902112 -0.21174143]]
# /tmp/ipykernel_3956/1683064091.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.random.normal(size=1000), hist=False)

# %% [markdown]
# ## Binomial Distribution

# %%
# Generate
x = np.random.binomial(n=10, p=0.5, size=10)

print(x)
sns.distplot(np.random.binomial(n=10, p=0.5, size=1000), hist=True, kde=False)

plt.show()
# Out:
# [4 6 4 6 7 4 4 5 7 4]
# /tmp/ipykernel_3956/1927514765.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.random.binomial(n=10, p=0.5, size=1000), hist=True, kde=False)

# %% [markdown]
# ## Normal and Binomial Distribution Together
# ### Binomial distribution is discrete whereas normal distribution is continuous, but with enough data they becomes similar

# %%
sns.distplot(np.random.normal(loc=50, scale=5, size=1000), hist=False, label='normal')
sns.distplot(np.random.binomial(n=100, p=0.5, size=1000), hist=False, label='binomial')
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_3956/2826904071.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.random.normal(loc=50, scale=5, size=1000), hist=False, label='normal')
# /tmp/ipykernel_3956/2826904071.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.random.binomial(n=100, p=0.5, size=1000), hist=False, label='binomial')

# %%
## Poisson Distribution

# %%
x = np.random.poisson(lam=2, size=10)
print(x)

sns.distplot(np.random.poisson(lam=2, size=1000), kde=False)

plt.show()
# Out:
# [1 1 1 3 1 1 1 1 3 3]
# /tmp/ipykernel_3956/3488712529.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.random.poisson(lam=2, size=1000), kde=False)

# %% [markdown]
# ## Binomial and Poisson distribution
# ### They become similar with large enough data

# %%
sns.distplot(np.random.normal(loc=50, scale=7, size=1000), hist=False, label='normal')
sns.distplot(np.random.poisson(lam=50, size=1000), hist=False, label='poisson')

plt.show()
# Out:
# /tmp/ipykernel_3956/3184726510.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.random.normal(loc=50, scale=7, size=1000), hist=False, label='normal')
# /tmp/ipykernel_3956/3184726510.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.random.poisson(lam=50, size=1000), hist=False, label='poisson')

# %% [markdown]
# ## Uniform Distribution

# %%
sns.distplot(np.random.uniform(size=1000), hist=False)

plt.show()
# Out:
# /tmp/ipykernel_3956/3815179616.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.random.uniform(size=1000), hist=False)

# %%
## Logistic Distribution

# %%
x = np.random.logistic(loc=1, scale=2, size=(2, 3))
print(x)

sns.distplot(np.random.logistic(size=1000), hist=False)

plt.show()
# Out:
# [[ 4.1357601  -0.10233788  4.66058658]
#  [-0.25695059  1.47888812 -2.45918917]]
# /tmp/ipykernel_3956/3497980000.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.random.logistic(size=1000), hist=False)

# %% [markdown]
# ## Logistic and Normal Distribution

# %%
sns.distplot(np.random.normal(scale=2, size=1000), hist=False, label='normal')
sns.distplot(np.random.logistic(size=1000), hist=False, label='logistic')
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_3956/1158202344.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.random.normal(scale=2, size=1000), hist=False, label='normal')
# /tmp/ipykernel_3956/1158202344.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.random.logistic(size=1000), hist=False, label='logistic')
