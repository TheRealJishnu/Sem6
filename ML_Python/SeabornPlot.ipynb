# %% [markdown]
# ## Import

# %%
# Imports
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Distplot

# %%
# sns.distplot([0, 1, 2, 3, 4, 5], hist=False)
sns.distplot([0, 1, 2, 3, 4, 5])

plt.show()
# Out:
# /tmp/ipykernel_5968/1725063175.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([0, 1, 2, 3, 4, 5])

# %% [markdown]
# ## Normal Distribution

# %%
# Generate a Random array
# x = np.random.normal(size=(2, 3))
# print(x)

# Generate a Random array with mean 1(loc) and standard deviation 2(scale)
x = np.random.normal(loc=1, scale=2, size=(2, 3))
print(x)

# Plotting
sns.distplot(np.random.normal(size=1000), hist=False)

plt.show()
# Out:
# [[ 2.50791697  1.7614617   3.12098776]
#  [ 2.71905334 -0.13506847  1.82540759]]
# /tmp/ipykernel_5968/1683064091.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.random.normal(size=1000), hist=False)

# %% [markdown]
# ## Binomial Distribution

# %%
# Generate
x = np.random.binomial(n=10, p=0.5, size=10)

print(x)
# Out:
# [6 2 5 6 2 5 6 8 7 2]
